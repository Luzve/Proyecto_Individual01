# %%
import pandas as pd

# %%
amazon = pd.read_csv(r'../Datasets/amazon_prime_titles.csv', encoding = 'utf-8')
amazon.head()
# Out:
#   show_id   type                 title        director  \
# 0      s1  Movie   The Grand Seduction    Don McKellar
# 1      s2  Movie  Take Care Good Night    Girish Joshi
# 2      s3  Movie  Secrets of Deception     Josh Webber
# 3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014    NaN  113 min            Comedy, Drama
# 1  March 30, 2021          2018    13+  110 min     Drama, International
# 2  March 30, 2021          2017    NaN   74 min  Action, Drama, Suspense
# 3  March 30, 2021          2014    NaN   69 min              Documentary
# 4  March 30, 2021          1989    NaN   45 min           Drama, Fantasy
#
#                                          description
# 0  A small fishing village must procure a local d...
# 1  A Metro Family decides to fight a Cyber Crimin...
# 2  After a man discovers his wife is cheating on ...
# 3  Pink breaks the mold once again, bringing her ...
# 4  Teenage Matt Banting wants to work with a famo...

# %%
amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9668 entries, 0 to 9667
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       9668 non-null   object
#  1   type          9668 non-null   object
#  2   title         9668 non-null   object
#  3   director      7586 non-null   object
#  4   cast          8435 non-null   object
#  5   country       672 non-null    object
#  6   date_added    155 non-null    object
#  7   release_year  9668 non-null   int64
#  8   rating        9331 non-null   object
#  9   duration      9668 non-null   object
#  10  listed_in     9668 non-null   object
#  11  description   9668 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 906.5+ KB

# %%
amazon.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2082
# cast            1233
# country         8996
# date_added      9513
# release_year       0
# rating           337
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
amazon.sample(5)
# Out:
#      show_id     type                                              title  \
# 1266   s1267  TV Show                                  Presunto Culpable
# 1975   s1976  TV Show  Kabaneri of the Iron Fortress (Original Japane...
# 974     s975    Movie                          Sleepytime Gorilla Museum
# 8180   s8181    Movie                                         The Cutter
# 590     s591  TV Show                                       The Kennedys
#
#             director                                               cast  \
# 1266             NaN  Miguel angel Muñoz, Susi Sanchez, Elvira Mingu...
# 1975             NaN                                                NaN
# 974     Baeble Music                                                NaN
# 8180  William Tannen  Chuck Norris, Joanna Pacula, Marshall Teague, ...
# 590              NaN  Katherine Parkinson, Dan Skinner, Lucy Hutchinson
#
#      country date_added  release_year rating  duration        listed_in  \
# 1266     NaN        NaN          2018     NR  1 Season  Drama, Suspense
# 1975     NaN        NaN          2016  TV-MA  1 Season            Anime
# 974      NaN        NaN          2011     NR    55 min           Comedy
# 8180     NaN        NaN          2006      R    91 min           Action
# 590      NaN        NaN          2015  TV-14  1 Season           Comedy
#
#                                             description
# 1266  Jon, un investigador que vuelve a su pueblo de...
# 1975  The world is overrun with Kabane, zombie-like ...
# 974   Experimental rockers Sleepytime Gorilla Museum...
# 8180  In the aftermath of a daring rescue mission go...
# 590   It's 1978, and Brenda, Tony and Emma Kennedy m...

# %%
disney=pd.read_csv(r'../Datasets/disney_plus_titles.csv', encoding = 'utf-8')
disney.head()
# Out:
#   show_id     type                                             title  \
# 0      s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1      s2    Movie                            Ernest Saves Christmas
# 2      s3    Movie                      Ice Age: A Mammoth Christmas
# 3      s4    Movie                        The Queen Family Singalong
# 4      s5  TV Show                             The Beatles: Get Back
#
#                             director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
# 2                       Karen Disher
# 3                    Hamish Hamilton
# 4                                NaN
#
#                                                 cast        country  \
# 0  Chris Diamantopoulos, Tony Anselmo, Tress MacN...            NaN
# 1           Jim Varney, Noelle Parker, Douglas Seale            NaN
# 2  Raymond Albert Romano, John Leguizamo, Denis L...  United States
# 3  Darren Criss, Adam Lambert, Derek Hough, Alexa...            NaN
# 4  John Lennon, Paul McCartney, George Harrison, ...            NaN
#
#           date_added  release_year rating  duration  \
# 0  November 26, 2021          2016   TV-G    23 min
# 1  November 26, 2021          1988     PG    91 min
# 2  November 26, 2021          2011   TV-G    23 min
# 3  November 26, 2021          2021  TV-PG    41 min
# 4  November 25, 2021          2021    NaN  1 Season
#
#                        listed_in  \
# 0              Animation, Family
# 1                         Comedy
# 2      Animation, Comedy, Family
# 3                        Musical
# 4  Docuseries, Historical, Music
#
#                                          description
# 0   Join Mickey and the gang as they duck the halls!
# 1  Santa Claus passes his magic bag to a new St. ...
# 2          Sid the Sloth is on Santa's naughty list.
# 3               This is real life, not just fantasy!
# 4  A three-part documentary from Peter Jackson ca...

# %%
hulu=pd.read_csv(r'../Datasets/hulu_titles.csv', encoding = 'utf-8')
hulu.head()
# Out:
#   show_id   type                           title director  cast country  \
# 0      s1  Movie  Ricky Velez: Here's Everything      NaN   NaN     NaN
# 1      s2  Movie                    Silent Night      NaN   NaN     NaN
# 2      s3  Movie                    The Marksman      NaN   NaN     NaN
# 3      s4  Movie                            Gaia      NaN   NaN     NaN
# 4      s5  Movie                        Settlers      NaN   NaN     NaN
#
#          date_added  release_year rating duration                  listed_in  \
# 0  October 24, 2021          2021  TV-MA      NaN           Comedy, Stand Up
# 1  October 23, 2021          2020    NaN   94 min     Crime, Drama, Thriller
# 2  October 23, 2021          2021  PG-13  108 min           Action, Thriller
# 3  October 22, 2021          2021      R   97 min                     Horror
# 4  October 22, 2021          2021    NaN  104 min  Science Fiction, Thriller
#
#                                          description
# 0  ​Comedian Ricky Velez bares it all with his ho...
# 1  Mark, a low end South London hitman recently r...
# 2  A hardened Arizona rancher tries to protect an...
# 3  A forest ranger and two survivalists with a cu...
# 4  Mankind's earliest settlers on the Martian fro...

# %%
netflix=pd.read_csv(r'../Datasets/amazon_prime_titles.csv', encoding = 'utf-8')
netflix.head()
# Out:
#   show_id   type                 title        director  \
# 0      s1  Movie   The Grand Seduction    Don McKellar
# 1      s2  Movie  Take Care Good Night    Girish Joshi
# 2      s3  Movie  Secrets of Deception     Josh Webber
# 3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014    NaN  113 min            Comedy, Drama
# 1  March 30, 2021          2018    13+  110 min     Drama, International
# 2  March 30, 2021          2017    NaN   74 min  Action, Drama, Suspense
# 3  March 30, 2021          2014    NaN   69 min              Documentary
# 4  March 30, 2021          1989    NaN   45 min           Drama, Fantasy
#
#                                          description
# 0  A small fishing village must procure a local d...
# 1  A Metro Family decides to fight a Cyber Crimin...
# 2  After a man discovers his wife is cheating on ...
# 3  Pink breaks the mold once again, bringing her ...
# 4  Teenage Matt Banting wants to work with a famo...

# %%
amazon_df=amazon.copy()
disney_df=disney.copy()
hulu_df=hulu.copy()
netflix_df=netflix.copy()

# %%
amazon_df['Plataforma']='amazon'
disney_df['Plataforma']='disney'
hulu_df['Plataforma']='hulu'
netflix_df['Plataforma']='netflix'

# %%
hulu_df['duration'].fillna('sin datos',inplace=True)
netflix_df['duration'].fillna('sin datos',inplace=True)

# %%
def sepdurationcolum(df):
    df['temporadas']=df['duration'].apply( lambda i: i.split()[0] if i.split()[1]=='Season' else '0')
    df['duracion_peliculas']=df['duration'].apply( lambda i: i.split()[0] if i.split(" ",1)[1]=='min' or i.split(" ",1)[1]=='min' else '0')
    return df

# %%
amazon_df=sepdurationcolum(amazon_df)
disney_df=sepdurationcolum(disney_df)
hulu_df=sepdurationcolum(hulu_df)
netflix_df=sepdurationcolum(netflix_df)

# %%
amazon_df.drop(columns='duration', inplace=True)
disney_df.drop(columns='duration', inplace=True)
hulu_df.drop(columns='duration', inplace=True)
netflix_df.drop(columns='duration', inplace=True)

# %%
final_df=pd.concat([amazon_df, disney_df, hulu_df, netflix_df], axis=0)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23859 entries, 0 to 9667
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   show_id             23859 non-null  object
#  1   type                23859 non-null  object
#  2   title               23859 non-null  object
#  3   director            16152 non-null  object
#  4   cast                18130 non-null  object
#  5   country             4195 non-null   object
#  6   date_added          4802 non-null   object
#  7   release_year        23859 non-null  int64
#  8   rating              22662 non-null  object
#  9   listed_in           23859 non-null  object
#  10  description         23855 non-null  object
#  11  Plataforma          23859 non-null  object
#  12  temporadas          23859 non-null  object
#  13  duracion_peliculas  23859 non-null  object
# dtypes: int64(1), object(13)
# memory usage: 2.7+ MB

# %% [markdown]
# SEGUNDA CONSULTA

# %%
((final_df['Plataforma']=='netflix') & (final_df['type'].str.contains('Movie'))).sum()
# Out:
# 7814

# %%
((final_df['Plataforma']=='netflix') & (final_df['type'].str.contains('TV Show'))).sum()
# Out:
# 1854

# %% [markdown]
# TERCERA CONSULTA

# %%
((final_df['listed_in'].str.contains('Comedy')) & (final_df['Plataforma']=='amazon')).sum()
# Out:
# 2099

# %% [markdown]
# CUARTA CONSULTA

# %%
final_df.sample(20)
# Out:
#      show_id     type                                              title  \
# 1039   s1040    Movie                                    Shakuntala Devi
# 4417   s4418    Movie                                           Dumb-ish
# 4016   s4017    Movie                 JFK's Women: The Scandals Revealed
# 5689   s5690    Movie                         Omerta: The Act Of Silence
# 8937   s8938    Movie                                3 Pints and a Rabbi
# 643     s644  TV Show                                          The Kings
# 263     s264  TV Show                                 Secrets Of The Zoo
# 2877   s2878  TV Show           Chasing The Crown: Dreamers to Streamers
# 3486   s3487    Movie                                            2ELEVEN
# 4474   s4475    Movie                                           Wetbacks
# 2980   s2981  TV Show                                Upstairs Downstairs
# 5532   s5533    Movie                        RiffTrax Live: Time Chasers
# 7151   s7152    Movie                                          Stag Hunt
# 8044   s8045    Movie                                     Concrete Plans
# 4513   s4514    Movie                                          Interlude
# 3661   s3662    Movie  Thomas & Friends: Big World! Big Adventures! -...
# 5546   s5547  TV Show                                             4 Cars
# 467     s468    Movie                Diary of a Wimpy Kid: The Long Haul
# 8518   s8519    Movie                    Butter (1998) (aka Never 2 Big)
# 7365   s7366    Movie                                     Apex Predators
#
#                    director  \
# 1039              Anu Menon
# 4417            Azim Lateef
# 4016          Harvey Lilley
# 5689         Craig Syracusa
# 8937       Richard J. Perry
# 643                     NaN
# 263                     NaN
# 2877                    NaN
# 3486            Derek Scott
# 4474            Hank McCune
# 2980                    NaN
# 5532      Michael J. Nelson
# 7151           James Shanks
# 8044         William Jewell
# 4513          Herve Bodilis
# 3661           David Stoten
# 5546                    NaN
# 467            David Bowers
# 8518  Peter Gathings Bunche
# 7365        Dustin Ferguson
#
#                                                    cast         country  \
# 1039  Vidya Balan, Sanya Malhotra, Jisshu Sengupta, ...           India
# 4417  Jennifer Hardwick, Mehgan James, Kendra LaChon...             NaN
# 4016         Andrew Cook, Piers Gibbon, Donald Rumbelow             NaN
# 5689                                                NaN             NaN
# 8937  Amanda Abbington, Michael Maloney, Jordan Step...             NaN
# 643                                                 NaN             NaN
# 263                                       Mocean Melvin             NaN
# 2877  Tucker Boner aka Jericho, AnneMunition, Action...             NaN
# 3486             Murda Pain, Chamar Avery, Martell Lane             NaN
# 4474  Lloyd Bridges, Nancy Gates, Barton MacLane, Jo...             NaN
# 2980                                                NaN  United Kingdom
# 5532  Michael J. Nelson, Kevin Murphy, Bill Corbett,...             NaN
# 7151                         Mackenzie Astin, Neil Cole             NaN
# 8044  Amber Rose Revah, Charley Palmer Rothwell, Chr...             NaN
# 4513  Vincent Winterhalter, Sopnie Verbeek, Dinara D...             NaN
# 3661                                                NaN             NaN
# 5546                                        Gren Brooke             NaN
# 467   Jason Drucker, Alicia Silverstone, Tom Scott, ...   United States
# 8518  Ernie Hudson, Nia Long, Tony Todd, Donnie Wahl...             NaN
# 7365                                                NaN             NaN
#
#               date_added  release_year rating  \
# 1039                 NaN          2020    13+
# 4417                 NaN          2015    18+
# 4016                 NaN          2006    13+
# 5689                 NaN          2021    18+
# 8937                 NaN          2021    18+
# 643         June 6, 2021          2021    NaN
# 263        April 2, 2021          2017  TV-PG
# 2877                 NaN          2020    13+
# 3486                 NaN          2017    18+
# 4474                 NaN          1956    18+
# 2980  September 24, 2013          2011  TV-14
# 5532                 NaN          2016    16+
# 7151                 NaN          2014    13+
# 8044                 NaN          2021    18+
# 4513                 NaN          2016      R
# 3661                 NaN          2018    NaN
# 5546                 NaN          2016    ALL
# 467        July 17, 2020          2017     PG
# 8518                 NaN          1998      R
# 7365                 NaN          2021    16+
#
#                                               listed_in  \
# 1039                                              Drama
# 4417                                             Comedy
# 4016                         Special Interest, Suspense
# 5689                                           Suspense
# 8937                            Comedy, Science Fiction
# 643                               Documentaries, Sports
# 263                Animals & Nature, Docuseries, Family
# 2877                                          Adventure
# 3486                                      Action, Drama
# 4474                                              Drama
# 2980                               Drama, International
# 5532                            Comedy, Science Fiction
# 7151                                  Action, Adventure
# 8044                                   Horror, Suspense
# 4513                              Comedy, International
# 3661                                    Animation, Kids
# 5546                                    Animation, Kids
# 467                                      Comedy, Family
# 8518  Action, Arts, Entertainment, and Culture, Susp...
# 7365                                             Action
#
#                                             description Plataforma temporadas  \
# 1039  The extraordinary story of Shakuntala Devi, th...     amazon          0
# 4417  DUMB-ISH is an urban classic tale about 2 room...    netflix          0
# 4016  John F. Kennedy was arguably the most charisma...    netflix          0
# 5689  At a time when political power and legal juris...     amazon          0
# 8937  When three dazed and confused strangers wake u...     amazon          0
# 643   A four-part series showcasing four champions w...       hulu          1
# 263   Go behind the scenes at The Columbus Zoo and A...     disney          0
# 2877  Three Twitch streamers have their sights set o...     amazon          1
# 3486  Ucult Studios presents a tale of the two broth...    netflix          0
# 4474  Former Coastguardsmen Jim Benson is about to l...    netflix          0
# 2980  Revival of the iconic '70s series set in a Lon...       hulu          0
# 5532  Time Chasers, the story of a man named Nick wh...     amazon          0
# 7151  Badly planned trek across Dartmoor landscape b...     amazon          0
# 8044  When their employer tries to cheat them out of...    netflix          0
# 4513  Raphaël buys a boat and convinces his two frie...     amazon          0
# 3661  Thomas is inspired to embark on an ambitious t...     amazon          0
# 5546  4 colored cars: red, yellow, green and blue. E...     amazon          1
# 467   A trip to Meemaw’s 90th birthday takes a detou...     disney          0
# 8518  Deceit, body heat and pulsing street beats con...     amazon          0
# 7365  When the bodies of beach-goers begin washing a...    netflix          0
#
#      duracion_peliculas
# 1039                127
# 4417                 68
# 4016                 52
# 5689                 85
# 8937                 73
# 643                   0
# 263                   0
# 2877                  0
# 3486                108
# 4474                 87
# 2980                  0
# 5532                106
# 7151                 93
# 8044                 91
# 4513                 95
# 3661                 82
# 5546                  0
# 467                  92
# 8518                101
# 7365                 70
